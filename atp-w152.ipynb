# %% [markdown]
# # Mini Project 2- Exploring AI Use by Demographic Features
#
# ## Using Dataset: Pew Research ATP W152, August 2024

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Include ATP W152- August 2024 Dataset

# %%
data = pd.read_csv('data/August 2024/ATP W152.csv')

# %%
display(data.describe())
display(data.head())
# Out:
#                QKEY  DEVICE_TYPE_W152  SVYMODE_W152    LANG_W152    FORM_W152  \
# count  5.410000e+03       5410.000000   5410.000000  5410.000000  5410.000000
# mean   1.869364e+11          1.688725      1.039741     9.023660     1.500739
# std    5.318192e+10          0.960277      0.195369     0.152001     0.500046
# min    1.003140e+05          1.000000      1.000000     9.000000     1.000000
# 25%    2.018011e+11          1.000000      1.000000     9.000000     1.000000
# 50%    2.020010e+11          1.000000      1.000000     9.000000     2.000000
# 75%    2.024000e+11          3.000000      1.000000     9.000000     2.000000
# max    2.024000e+11          4.000000      2.000000    10.000000     2.000000
#
#        AI_HEARD_W152  CNCEXC_W152   USEAI_W152  AICONTROL1_W152  \
# count    5410.000000   5410.00000  5410.000000      5410.000000
# mean        1.913124      2.82902     4.211460         4.131423
# std         5.480991      7.33057     7.546541         7.155505
# min         1.000000      1.00000     1.000000         1.000000
# 25%         1.000000      2.00000     2.000000         3.000000
# 50%         2.000000      2.00000     4.000000         4.000000
# 75%         2.000000      3.00000     5.000000         4.000000
# max        99.000000     99.00000    99.000000        99.000000
#
#        AICONTROL2_W152  ...  F_PARTYLN_FINAL  F_PARTYSUM_FINAL  \
# count      5410.000000  ...      2365.000000       5410.000000
# mean          2.363216  ...         9.648626          1.797597
# std           5.464507  ...        26.944175          1.483587
# min           1.000000  ...         1.000000          1.000000
# 25%           2.000000  ...         1.000000          1.000000
# 50%           2.000000  ...         2.000000          2.000000
# 75%           2.000000  ...         2.000000          2.000000
# max          99.000000  ...        99.000000          9.000000
#
#        F_PARTYSUMIDEO_FINAL        F_REG   F_INC_SDT1       F_IDEO  \
# count           5410.000000  5410.000000  5410.000000  5410.000000
# mean               2.782810     1.412754    10.103327     4.836969
# std                1.794066     0.767634    20.203061    13.480087
# min                1.000000     1.000000     1.000000     1.000000
# 25%                1.000000     1.000000     3.000000     2.000000
# 50%                3.000000     1.000000     6.000000     3.000000
# 75%                4.000000     1.000000     9.000000     4.000000
# max                9.000000     3.000000    99.000000    99.000000
#
#          F_INTFREQ     F_VOLSUM  F_INC_TIER2  WEIGHT_W152
# count  5410.000000  5410.000000  5410.000000  5410.000000
# mean      2.125508     2.201664     7.882625     1.000000
# std       6.403944     6.997570    23.273008     0.595664
# min       1.000000     1.000000     1.000000     0.135260
# 25%       1.000000     1.000000     1.000000     0.685758
# 50%       2.000000     2.000000     2.000000     0.907527
# 75%       2.000000     2.000000     3.000000     1.161045
# max      99.000000    99.000000    99.000000     3.737946
#
# [8 rows x 104 columns]
#      QKEY  INTERVIEW_START_W152    INTERVIEW_END_W152  DEVICE_TYPE_W152  \
# 0  100314  15-Aug-2024 15:30:49  15-Aug-2024 15:40:52                 1
# 1  103379  15-Aug-2024 13:58:04  15-Aug-2024 14:21:23                 3
# 2  104727  15-Aug-2024 07:18:22  15-Aug-2024 07:24:47                 1
# 3  106590  13-Aug-2024 22:30:51  13-Aug-2024 22:36:57                 1
# 4  107668  13-Aug-2024 15:23:41  13-Aug-2024 15:30:23                 1
#
#    SVYMODE_W152  LANG_W152  FORM_W152  AI_HEARD_W152  CNCEXC_W152  USEAI_W152  \
# 0             1          9          1              2            2           5
# 1             1          9          1              2            2           5
# 2             1          9          2              2            3           5
# 3             1          9          1              2            2           5
# 4             1          9          2              2            2           3
#
#    ...  F_PARTYLN_FINAL  F_PARTYSUM_FINAL  F_PARTYSUMIDEO_FINAL  F_REG  \
# 0  ...              NaN                 1                     2      1
# 1  ...              NaN                 1                     1      1
# 2  ...              NaN                 1                     1      1
# 3  ...              1.0                 1                     2      1
# 4  ...              1.0                 1                     2      1
#
#    F_INC_SDT1  F_IDEO  F_INTFREQ  F_VOLSUM  F_INC_TIER2  WEIGHT_W152
# 0           7       3          3         1            2     0.639769
# 1           9       2          5         2            3     1.338840
# 2          99       2          2         2           99     0.909360
# 3           8       3          2         1            2     0.919896
# 4           9       3          1         1            3     0.719993
#
# [5 rows x 106 columns]

# %%
for i in data.columns.to_list():
    print(i)
# Out:
# QKEY
# INTERVIEW_START_W152
# INTERVIEW_END_W152
# DEVICE_TYPE_W152
# SVYMODE_W152
# LANG_W152
# FORM_W152
# AI_HEARD_W152
# CNCEXC_W152
# USEAI_W152
# AICONTROL1_W152
# AICONTROL2_W152
# AICHANGE_W152
# AIFUTRIMPCT_a_W152
# AIFUTRIMPCT_b_W152
# AIFUTRIMPCT_c_W152
# AIFUTRIMPCT_d_W152
# AIFUTRIMPCT_e_W152
# AIFUTRIMPCT_f_W152
# AIFUTRIMPCT_g_W152
# AIFUTRIMPCT_h_W152
# AIFUTRIMPCT_i_W152
# AIFUTRIMPCT_j_W152
# AIJOBS_W152
# AIJOBIMPCT_a_W152
# AIJOBIMPCT_b_W152
# AIJOBIMPCT_c_W152
# AIJOBIMPCT_d_W152
# AIJOBIMPCT_e_W152
# AIJOBIMPCT_f_W152
# AIJOBIMPCT_g_W152
# AIJOBIMPCT_h_W152
# AIJOBIMPCT_i_W152
# AIJOBIMPCT_j_W152
# HUMANVAI_a_W152
# HUMANVAI_b_W152
# HUMANVAI_c_W152
# HUMANVAI_d_W152
# HUMANVAI_e_W152
# HUMANVAI_f_W152
# HUMANVAI_g_W152
# HUMANVAI_h_W152
# PERSBENHRM_W152
# TRSTAIPRS_W152
# AICONCERN_a_W152
# AICONCERN_b_W152
# AICONCERN_c_W152
# AICONCERN_d_W152
# AICONCERN_e_W152
# AICONCERN_f_W152
# AICONCERN_g_W152
# FUTRAI_a_W152
# FUTRAI_b_W152
# FUTRAI_c_W152
# FUTRAI_d_W152
# DISCRIM1_a_W152
# DISCRIM1_b_W152
# DISCRIM1_c_W152
# DISCRIM1_d_W152
# DISCRIM1_e_W152
# DISCRIM1_f_W152
# AIREG_W152
# REGCONFG_W152
# REGCONFI_W152
# CHATAWARE_W152
# CHATUSE_W152
# CHATHELPFUL_W152
# DRIVE1_W152
# DRIVE2_a_W152
# DRIVE2_b_W152
# DRIVE2_c_W152
# DRIVE2_d_W152
# DRIVE2_e_W152
# DRIVE2_f_W152
# DRIVE3_W152
# DRIVER_W152
# F_METRO
# F_CREGION
# F_CDIVISION
# F_USR_SELFID
# F_AGECAT
# F_GENDER
# F_EDUCCAT
# F_EDUCCAT2
# F_HISP
# F_HISP_ORIGIN
# F_YEARSINUS_RECODE
# F_RACECMB
# F_RACETHNMOD
# F_BIRTHPLACE
# F_MARITAL
# F_RELIG
# F_BORN
# F_RELIGCAT1
# F_ATTENDPER
# F_PARTY_FINAL
# F_PARTYLN_FINAL
# F_PARTYSUM_FINAL
# F_PARTYSUMIDEO_FINAL
# F_REG
# F_INC_SDT1
# F_IDEO
# F_INTFREQ
# F_VOLSUM
# F_INC_TIER2
# WEIGHT_W152

# %%
data.drop_duplicates(inplace=True)
data.dropna(how='all', inplace=True)

# %% [markdown]
# ## Subset for Regression Models
# - `QKEY` is the unique identifier (id) per row
# - Including predictor and outcome variables planned for logit and ols models
# - Outcome variables:
#     - `CHATUSE_W152` is binary (coded 1, 2) for logit
#     - `USEAI_W152` is likert for ols

# %%
predictor_cols = ['F_INC_SDT1', 'F_EDUCCAT2', 'F_AGECAT', 'F_GENDER', 'F_RACECMB', 'F_RACETHNMOD']
outcome_cols = ['CHATUSE_W152', 'USEAI_W152']
include_cols = ['QKEY'] + predictor_cols + outcome_cols
data = data[include_cols]
data.head(20)
# Out:
#       QKEY  F_INC_SDT1  F_EDUCCAT2  F_AGECAT  F_GENDER  F_RACECMB  \
# 0   100314           7           3         4         1          1
# 1   103379           9           3         4         1          1
# 2   104727          99           2         3         1          1
# 3   106590           8           6         3         2          1
# 4   107668           9           5         3         2          1
# 5   108435           9           6         4         2          1
# 6   108592           5           4         4         2          2
# 7   112238           6           2         4         2          1
# 8   112371           3           4         3         2          1
# 9   116422           5           2         4         2          1
# 10  116591           2           2         4         2          1
# 11  118110          99           2         3         2          1
# 12  118218           3           4         4         2          1
# 13  126211           2           2         4         1          1
# 14  127160           5           6         2         2          5
# 15  127284           6           3         3         2          1
# 16  133700           2           2         4         2          1
# 17  144736           9           6         3         2          1
# 18  145364           9           2         3         1          1
# 19  145447           9           6         4         2          1
#
#     F_RACETHNMOD  CHATUSE_W152  USEAI_W152
# 0              1           NaN           5
# 1              1           NaN           5
# 2              1           NaN           5
# 3              1           NaN           5
# 4              1           2.0           3
# 5              1           2.0           2
# 6              2           2.0           3
# 7              1           NaN           5
# 8              3           2.0           5
# 9              1           NaN           5
# 10             1           NaN           5
# 11             1           NaN           5
# 12             1           2.0           2
# 13             1           2.0           2
# 14             4           2.0           5
# 15             1           2.0           2
# 16             1           NaN           5
# 17             1           1.0           2
# 18             1           2.0           2
# 19             1           1.0           4

# %% [markdown]
# ## Recode Variables

# %%
# 99 = "Refused" code; recode as missing
recode_99_cols = predictor_cols + outcome_cols
for col in recode_99_cols:
    data[col] = data[col].replace(99, np.nan)

# Remap Binary Outcome Variable
data['CHATUSE_W152'] = data['CHATUSE_W152'].replace({2: 0})  # 1 = Yes, have used, 0 = No, have not used

display(data.describe())
display(data.head(20))
# Out:
#                QKEY   F_INC_SDT1   F_EDUCCAT2     F_AGECAT     F_GENDER  \
# count  5.410000e+03  5150.000000  5397.000000  5383.000000  5387.000000
# mean   1.869364e+11     5.615340     3.821197     2.625859     1.506590
# std    5.318192e+10     3.095709     1.564434     1.017907     0.511385
# min    1.003140e+05     1.000000     1.000000     1.000000     1.000000
# 25%    2.018011e+11     3.000000     2.000000     2.000000     1.000000
# 50%    2.020010e+11     6.000000     4.000000     3.000000     2.000000
# 75%    2.024000e+11     9.000000     5.000000     4.000000     2.000000
# max    2.024000e+11     9.000000     6.000000     4.000000     3.000000
#
#          F_RACECMB  F_RACETHNMOD  CHATUSE_W152   USEAI_W152
# count  5327.000000   5364.000000   4027.000000  5377.000000
# mean      1.631312      1.960291      0.497393     3.629719
# std       1.091040      1.348927      0.500055     1.344893
# min       1.000000      1.000000      0.000000     1.000000
# 25%       1.000000      1.000000      0.000000     2.000000
# 50%       1.000000      1.000000      0.000000     4.000000
# 75%       2.000000      3.000000      1.000000     5.000000
# max       5.000000      5.000000      1.000000     5.000000
#       QKEY  F_INC_SDT1  F_EDUCCAT2  F_AGECAT  F_GENDER  F_RACECMB  \
# 0   100314         7.0         3.0       4.0       1.0        1.0
# 1   103379         9.0         3.0       4.0       1.0        1.0
# 2   104727         NaN         2.0       3.0       1.0        1.0
# 3   106590         8.0         6.0       3.0       2.0        1.0
# 4   107668         9.0         5.0       3.0       2.0        1.0
# 5   108435         9.0         6.0       4.0       2.0        1.0
# 6   108592         5.0         4.0       4.0       2.0        2.0
# 7   112238         6.0         2.0       4.0       2.0        1.0
# 8   112371         3.0         4.0       3.0       2.0        1.0
# 9   116422         5.0         2.0       4.0       2.0        1.0
# 10  116591         2.0         2.0       4.0       2.0        1.0
# 11  118110         NaN         2.0       3.0       2.0        1.0
# 12  118218         3.0         4.0       4.0       2.0        1.0
# 13  126211         2.0         2.0       4.0       1.0        1.0
# 14  127160         5.0         6.0       2.0       2.0        5.0
# 15  127284         6.0         3.0       3.0       2.0        1.0
# 16  133700         2.0         2.0       4.0       2.0        1.0
# 17  144736         9.0         6.0       3.0       2.0        1.0
# 18  145364         9.0         2.0       3.0       1.0        1.0
# 19  145447         9.0         6.0       4.0       2.0        1.0
#
#     F_RACETHNMOD  CHATUSE_W152  USEAI_W152
# 0            1.0           NaN         5.0
# 1            1.0           NaN         5.0
# 2            1.0           NaN         5.0
# 3            1.0           NaN         5.0
# 4            1.0           0.0         3.0
# 5            1.0           0.0         2.0
# 6            2.0           0.0         3.0
# 7            1.0           NaN         5.0
# 8            3.0           0.0         5.0
# 9            1.0           NaN         5.0
# 10           1.0           NaN         5.0
# 11           1.0           NaN         5.0
# 12           1.0           0.0         2.0
# 13           1.0           0.0         2.0
# 14           4.0           0.0         5.0
# 15           1.0           0.0         2.0
# 16           1.0           NaN         5.0
# 17           1.0           1.0         2.0
# 18           1.0           0.0         2.0
# 19           1.0           1.0         4.0

# %%
# Save cleaned/recoded data for regression analysis
data.to_csv('data/August 2024/atp-w152-clean.csv', index=False)

# %% [markdown]
# ## Logistic Regression

# %%
data = data.dropna()
data.describe()
# Out:
#                QKEY   F_INC_SDT1   F_EDUCCAT2     F_AGECAT     F_GENDER  \
# count  3.796000e+03  3796.000000  3796.000000  3796.000000  3796.000000
# mean   1.878028e+11     6.089305     4.089831     2.452845     1.463119
# std    5.176870e+10     2.997791     1.517085     0.979979     0.513798
# min    1.076680e+05     1.000000     1.000000     1.000000     1.000000
# 25%    2.018011e+11     3.000000     3.000000     2.000000     1.000000
# 50%    2.020010e+11     7.000000     5.000000     2.000000     1.000000
# 75%    2.024000e+11     9.000000     5.000000     3.000000     2.000000
# max    2.024000e+11     9.000000     6.000000     4.000000     3.000000
#
#          F_RACECMB  F_RACETHNMOD  CHATUSE_W152   USEAI_W152
# count  3796.000000   3796.000000   3796.000000  3796.000000
# mean      1.667808      2.043730      0.500263     3.382771
# std       1.101216      1.427265      0.500066     1.337296
# min       1.000000      1.000000      0.000000     1.000000
# 25%       1.000000      1.000000      0.000000     2.000000
# 50%       1.000000      1.000000      1.000000     3.000000
# 75%       2.000000      3.000000      1.000000     5.000000
# max       5.000000      5.000000      1.000000     5.000000

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

np.random.seed(42)

# Gender_2 Female
# Gender_3 In some other way
gender_dummies = pd.get_dummies(data['F_GENDER'], prefix='Gender', drop_first=True, dtype=int)
race_dummies = pd.get_dummies(data['F_RACECMB'].astype(str), prefix='Race', drop_first=True, dtype=int)

X = pd.concat([data[['F_INC_SDT1','F_EDUCCAT2','F_AGECAT']], gender_dummies, race_dummies], axis=1)
y = data["CHATUSE_W152"]

X = sm.add_constant(X)

# Renaming columns for interpretability
rename_dict = {
    "const": "Intercept",
    "F_INC_SDT1": "Income",
    "F_AGECAT": "Age",
    "F_EDUCCAT2": "Education",
    "Gender_2.0": "Gender: Female",
    "Gender_3.0": "Gender: In some other way",
    "Race_2.0": "Race: Black or African-American",
    "Race_3.0": "Race: Asian or Asian-American",
    "Race_4.0": "Race: Mixed Race",
    "Race_5.0": "Race: Other"  
}

X = X.rename(columns=rename_dict)

logreg = sm.Logit(y, X)
logreg_results = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.615824
#          Iterations 5

# %%
print(logreg_results.summary()) # the regular table is not very intepretable because of log odds
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           CHATUSE_W152   No. Observations:                 3796
# Model:                          Logit   Df Residuals:                     3786
# Method:                           MLE   Df Model:                            9
# Date:                Wed, 20 May 2026   Pseudo R-squ.:                  0.1116
# Time:                        22:15:03   Log-Likelihood:                -2337.7
# converged:                       True   LL-Null:                       -2631.2
# Covariance Type:            nonrobust   LLR p-value:                1.266e-120
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           0.2817      0.145      1.947      0.052      -0.002       0.565
# Income                              0.0722      0.013      5.435      0.000       0.046       0.098
# Education                           0.2406      0.026      9.268      0.000       0.190       0.292
# Age                                -0.6685      0.038    -17.383      0.000      -0.744      -0.593
# Gender: Female                     -0.3624      0.072     -5.023      0.000      -0.504      -0.221
# Gender: In some other way           0.0619      0.417      0.148      0.882      -0.755       0.878
# Race: Black or African-American     0.1966      0.113      1.745      0.081      -0.024       0.417
# Race: Asian or Asian-American       0.4889      0.111      4.407      0.000       0.271       0.706
# Race: Mixed Race                    0.0580      0.161      0.360      0.719      -0.258       0.374
# Race: Other                        -0.0438      0.190     -0.231      0.817      -0.415       0.328
# ===================================================================================================

# %%
df_odds = logreg_results.conf_int()
df_odds["Odds Ratio"] = logreg_results.params
df_odds.columns = ["CI lower", "CI Upper", "Odds Ratio"]

# converting from log odds to odds ratios for intepretabiliy
df_odds = np.exp(df_odds)

# percent change
df_odds["% Change"] = (df_odds["Odds Ratio"] - 1) * 100

# CI effect
conditions = [
    (df_odds["CI lower"] > 1.0) & (df_odds["CI Upper"] > 1.0),  # Entirely above 1
    (df_odds["CI lower"] < 1.0) & (df_odds["CI Upper"] < 1.0),  # Entirely below 1
]
choices = ["Positive Effect", "Negative Effect"]
df_odds["CI Effect"] = np.select(conditions, choices, default="No Effect")

# P-value
df_odds["P-value"] = logreg_results.pvalues
df_odds["Significant"] = df_odds["P-value"] < 0.05

df_odds = df_odds[["Odds Ratio","% Change","CI lower","CI Upper","CI Effect","P-value","Significant"]]

df_odds
# Out:
#                                  Odds Ratio   % Change  CI lower  CI Upper  \
# Intercept                          1.325429  32.542878  0.998145  1.760027
# Income                             1.074882   7.488221  1.047252  1.103242
# Education                          1.272070  27.206990  1.208954  1.338481
# Age                                0.512486 -48.751379  0.475278  0.552608
# Gender: Female                     0.696018 -30.398188  0.604240  0.801736
# Gender: In some other way          1.063818   6.381795  0.470161  2.407064
# Race: Black or African-American    1.217225  21.722474  0.976063  1.517972
# Race: Asian or Asian-American      1.630574  63.057429  1.311896  2.026664
# Race: Mixed Race                   1.059757   5.975746  0.772298  1.454213
# Race: Other                        0.957151  -4.284864  0.660079  1.387923
#
#                                        CI Effect       P-value  Significant
# Intercept                              No Effect  5.151933e-02        False
# Income                           Positive Effect  5.487784e-08         True
# Education                        Positive Effect  1.893266e-20         True
# Age                              Negative Effect  1.118792e-67         True
# Gender: Female                   Negative Effect  5.090978e-07         True
# Gender: In some other way              No Effect  8.819530e-01        False
# Race: Black or African-American        No Effect  8.100208e-02        False
# Race: Asian or Asian-American    Positive Effect  1.049278e-05         True
# Race: Mixed Race                       No Effect  7.192170e-01        False
# Race: Other                            No Effect  8.173273e-01        False

# %% [markdown]
# ## Interpretation
#
# ### Income
# As CI bounds are above 1.0, income has a positive effect on AI usage. The result is significant (p < 0.05). With one unit increase in income, the odds of using AI increase by 7.48%.
#
# ### Education
# As CI bounds are above 1.0, education has a positive effect on AI usage. The result is significant (p < 0.05). With one unit increase in education, the odds of using AI increase by 27.20%.
#
# ### Age
# As CI bounds are below 1.0, age has a negative effect on AI usage. The result is significant (p < 0.05). For each one bracket increase in the age category (moving up from 18–29, to 30–49, to 50–64, and 65+), the odds of using AI decrease by 48.75%.
#
# ### Gender: Female [baseline Male]
# As CI bounds are below 1.0, female gender has a negative effect on AI usage. The result is significant (p < 0.05). For females the odds of using AI decrease by 30.39% compared to males.
#
# ### Gender: In some other way [baseline Male]
# As CI bounds include 1.0, there is no significant effect of "in some other way" gender on AI usage. The result is not significant (p > 0.05).
#
# ### Race: Black or African-American [baseline White]
# As CI bounds include 1.0, there is no significant effect of Black or African-American Race on AI usage. The result is not significant (p > 0.05).
#
# ### Race: Asian or Asian-American [baseline White]
# As CI bounds are above 1.0, Asian or Asian-American Race has a positive effect on AI usage. For Asian or Asian-American Race the odds of using AI increase by 63.05% compared to White.
#
# ### Race: Mixed Race [baseline White]
# As CI bounds include 1.0, there is no significant effect of Mixed Race on AI usage. The result is not significant (p > 0.05).
#
# ### Race: Other [baseline White]
# As CI bounds include 1.0, there is no significant effect of Black or Other Race on AI usage. The result is not significant (p > 0.05).
