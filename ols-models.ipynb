# %% [markdown]
# # Mini Project 2- Exploring AI Use by Demographic Features
#
# ## Using Dataset: Pew Research ATP W152, August 2024

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %% [markdown]
# Include cleaned dataset, prepared in `atp-w152.ipynb`

# %%
data = pd.read_csv('data/August 2024/atp-w152-clean.csv')

# %% [markdown]
# # OLS Regression Models predicting `USEAI_W152` likert
#
# - 1	Almost constantly
# - 2	Several times a day
# - 3	About once a day
# - 4	Several times a week
# - 5	Less often
#
# ## OLS Model 1: Income Only

# %%
# USEAI_W152 (Likert 1-5) regressed on household income only
model1 = smf.ols('USEAI_W152 ~ C(F_INC_SDT1)', data=data).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             USEAI_W152   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     26.27
# Date:                Wed, 20 May 2026   Prob (F-statistic):           3.41e-40
# Time:                        14:31:33   Log-Likelihood:                -8679.6
# No. Observations:                5118   AIC:                         1.738e+04
# Df Residuals:                    5109   BIC:                         1.744e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                4.0050      0.047     85.745      0.000       3.913       4.097
# C(F_INC_SDT1)[T.2.0]    -0.1271      0.079     -1.615      0.106      -0.281       0.027
# C(F_INC_SDT1)[T.3.0]    -0.1434      0.080     -1.790      0.073      -0.300       0.014
# C(F_INC_SDT1)[T.4.0]    -0.3481      0.083     -4.216      0.000      -0.510      -0.186
# C(F_INC_SDT1)[T.5.0]    -0.3583      0.083     -4.307      0.000      -0.521      -0.195
# C(F_INC_SDT1)[T.6.0]    -0.3310      0.083     -3.969      0.000      -0.495      -0.168
# C(F_INC_SDT1)[T.7.0]    -0.4406      0.089     -4.947      0.000      -0.615      -0.266
# C(F_INC_SDT1)[T.8.0]    -0.3946      0.087     -4.547      0.000      -0.565      -0.224
# C(F_INC_SDT1)[T.9.0]    -0.7180      0.056    -12.719      0.000      -0.829      -0.607
# ==============================================================================
# Omnibus:                     4140.171   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              424.323
# Skew:                          -0.378   Prob(JB):                     7.24e-93
# Kurtosis:                       1.809   Cond. No.                         9.02
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## OLS Model 2: Education Only

# %%
# USEAI_W152 regressed on education only
model2 = smf.ols('USEAI_W152 ~ C(F_EDUCCAT)', data=data).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             USEAI_W152   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     150.7
# Date:                Wed, 20 May 2026   Prob (F-statistic):           2.11e-64
# Time:                        14:31:33   Log-Likelihood:                -9053.7
# No. Observations:                5364   AIC:                         1.811e+04
# Df Residuals:                    5361   BIC:                         1.813e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               3.3133      0.027    121.346      0.000       3.260       3.367
# C(F_EDUCCAT)[T.2.0]     0.3704      0.042      8.726      0.000       0.287       0.454
# C(F_EDUCCAT)[T.3.0]     0.7580      0.044     17.245      0.000       0.672       0.844
# ==============================================================================
# Omnibus:                     2861.353   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              425.417
# Skew:                          -0.393   Prob(JB):                     4.19e-93
# Kurtosis:                       1.866   Cond. No.                         3.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## OLS Model 3: Income + Education

# %%
# Additive model: income and education together
model3 = smf.ols('USEAI_W152 ~ C(F_INC_SDT1) + C(F_EDUCCAT)', data=data).fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             USEAI_W152   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     35.20
# Date:                Wed, 20 May 2026   Prob (F-statistic):           3.79e-67
# Time:                        14:31:33   Log-Likelihood:                -8605.0
# No. Observations:                5114   AIC:                         1.723e+04
# Df Residuals:                    5103   BIC:                         1.730e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                3.6006      0.058     61.553      0.000       3.486       3.715
# C(F_INC_SDT1)[T.2.0]    -0.0678      0.078     -0.871      0.384      -0.221       0.085
# C(F_INC_SDT1)[T.3.0]    -0.0623      0.079     -0.785      0.432      -0.218       0.093
# C(F_INC_SDT1)[T.4.0]    -0.2109      0.082     -2.558      0.011      -0.372      -0.049
# C(F_INC_SDT1)[T.5.0]    -0.2146      0.083     -2.585      0.010      -0.377      -0.052
# C(F_INC_SDT1)[T.6.0]    -0.1660      0.084     -1.982      0.048      -0.330      -0.002
# C(F_INC_SDT1)[T.7.0]    -0.2654      0.089     -2.975      0.003      -0.440      -0.091
# C(F_INC_SDT1)[T.8.0]    -0.1807      0.088     -2.064      0.039      -0.352      -0.009
# C(F_INC_SDT1)[T.9.0]    -0.4324      0.061     -7.108      0.000      -0.552      -0.313
# C(F_EDUCCAT)[T.2.0]      0.2758      0.045      6.083      0.000       0.187       0.365
# C(F_EDUCCAT)[T.3.0]      0.5820      0.050     11.701      0.000       0.484       0.680
# ==============================================================================
# Omnibus:                     2120.615   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              378.446
# Skew:                          -0.380   Prob(JB):                     6.63e-83
# Kurtosis:                       1.905   Cond. No.                         10.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## OLS Model 4: Income * Education

# %%
# Interaction model: '*' expands to both main effects + the interaction term
model4 = smf.ols('USEAI_W152 ~ F_INC_SDT1 * F_EDUCCAT', data=data).fit()
print(model4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             USEAI_W152   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     114.2
# Date:                Wed, 20 May 2026   Prob (F-statistic):           1.32e-71
# Time:                        14:34:35   Log-Likelihood:                -8609.6
# No. Observations:                5114   AIC:                         1.723e+04
# Df Residuals:                    5110   BIC:                         1.725e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                3.2887      0.114     28.841      0.000       3.065       3.512
# F_INC_SDT1              -0.0394      0.016     -2.448      0.014      -0.071      -0.008
# F_EDUCCAT                0.3233      0.049      6.631      0.000       0.228       0.419
# F_INC_SDT1:F_EDUCCAT    -0.0053      0.008     -0.683      0.495      -0.021       0.010
# ==============================================================================
# Omnibus:                     2165.205   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              378.312
# Skew:                          -0.377   Prob(JB):                     7.09e-83
# Kurtosis:                       1.901   Cond. No.                         86.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## OLS Model 5: Income + Education + Age + Gender + Race

# %%
# Full model: income/education/age as continuous ordinal scales;
# gender and race wrapped in C() since they are nominal categories
model5 = smf.ols(
    'USEAI_W152 ~ C(F_INC_SDT1) + C(F_EDUCCAT) + C(F_AGECAT) + C(F_GENDER) + C(F_RACECMB)',
    data=data
).fit()
print(model5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             USEAI_W152   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     27.64
# Date:                Wed, 20 May 2026   Prob (F-statistic):           4.67e-94
# Time:                        14:31:33   Log-Likelihood:                -8402.3
# No. Observations:                5043   AIC:                         1.684e+04
# Df Residuals:                    5023   BIC:                         1.698e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                3.2071      0.079     40.603      0.000       3.052       3.362
# C(F_INC_SDT1)[T.2.0]    -0.0557      0.078     -0.718      0.473      -0.208       0.096
# C(F_INC_SDT1)[T.3.0]    -0.0382      0.079     -0.484      0.629      -0.193       0.117
# C(F_INC_SDT1)[T.4.0]    -0.1874      0.082     -2.283      0.022      -0.348      -0.026
# C(F_INC_SDT1)[T.5.0]    -0.1869      0.083     -2.264      0.024      -0.349      -0.025
# C(F_INC_SDT1)[T.6.0]    -0.1346      0.084     -1.607      0.108      -0.299       0.030
# C(F_INC_SDT1)[T.7.0]    -0.2123      0.089     -2.391      0.017      -0.386      -0.038
# C(F_INC_SDT1)[T.8.0]    -0.1534      0.088     -1.751      0.080      -0.325       0.018
# C(F_INC_SDT1)[T.9.0]    -0.3685      0.062     -5.921      0.000      -0.491      -0.246
# C(F_EDUCCAT)[T.2.0]      0.2424      0.045      5.336      0.000       0.153       0.331
# C(F_EDUCCAT)[T.3.0]      0.5338      0.050     10.661      0.000       0.436       0.632
# C(F_AGECAT)[T.2.0]       0.1588      0.057      2.762      0.006       0.046       0.272
# C(F_AGECAT)[T.3.0]       0.3605      0.061      5.870      0.000       0.240       0.481
# C(F_AGECAT)[T.4.0]       0.6175      0.061     10.080      0.000       0.497       0.738
# C(F_GENDER)[T.2.0]       0.1586      0.037      4.300      0.000       0.086       0.231
# C(F_GENDER)[T.3.0]       0.1370      0.237      0.578      0.564      -0.328       0.602
# C(F_RACECMB)[T.2.0]      0.0511      0.057      0.901      0.368      -0.060       0.162
# C(F_RACECMB)[T.3.0]     -0.1058      0.061     -1.729      0.084      -0.226       0.014
# C(F_RACECMB)[T.4.0]     -0.1302      0.086     -1.517      0.129      -0.299       0.038
# C(F_RACECMB)[T.5.0]      0.2017      0.095      2.113      0.035       0.015       0.389
# ==============================================================================
# Omnibus:                     1534.138   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              334.466
# Skew:                          -0.356   Prob(JB):                     2.35e-73
# Kurtosis:                       1.959   Cond. No.                         18.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
